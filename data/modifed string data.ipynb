# %%
import pandas as pd

# %%
df=pd.read_csv('nfl_football_team_stats.csv')
df
# Out:
#       Unnamed: 0  Year      Date  GameNumber GameLocation  \
# 0              0  2010    9/9/10           1         Away
# 1              1  2010    9/9/10           1         Home
# 2              2  2010   9/12/10           1         Away
# 3              3  2010   9/12/10           1         Away
# 4              4  2010   9/12/10           1         Away
# ...          ...   ...       ...         ...          ...
# 4088        4088  2017  11/26/17          11         Home
# 4089        4089  2017  11/27/17          11         Away
# 4090        4090  2017  11/27/17          11         Home
# 4091        4091  2017  11/30/17          12         Away
# 4092        4092  2017  11/30/17          12         Home
#
#                      Team  TeamScore             Opponent  OppponentScore  \
# 0       Minnesota Vikings          9   New Orleans Saints              14
# 1      New Orleans Saints         14    Minnesota Vikings               9
# ...

# %%
df.Year= df.Year.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4093 entries, 0 to 4092
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           4093 non-null   object
#  1   Date                           4093 non-null   object
#  2   GameNumber                     4093 non-null   int64
#  3   GameLocation                   4093 non-null   object
#  4   Team                           4093 non-null   object
#  5   TeamScore                      4093 non-null   int64
#  6   Opponent                       4093 non-null   object
#  7   OppponentScore                 4093 non-null   int64
#  8   Result                         4093 non-null   object
#  9   PassingAttempts                4093 non-null   int64
#  10  PassingCompletions             4093 non-null   int64
#  11  PassingInterceptions           4093 non-null   int64
# ...

# %%
df.to_csv('nfl_football_team_stats.csv')
